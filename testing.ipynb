# %%
### Preamble: imports and stuff like that ###
# %matplotlib inline
import TimeSeries

# %%
armodel = TimeSeries.Generator().generate(100000, p=3, alpha = [0.2, 0.3, 0.5])
armodel.plot()

# %%
mamodel = TimeSeries.Generator(type="movingaverage").generate(1000, q = 3, theta=[5, 0.2, 0.1], mu = 40)
mamodel.plot()
